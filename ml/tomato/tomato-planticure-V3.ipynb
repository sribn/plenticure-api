# %%
import os
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from google.colab import drive

# %% [markdown]
# ## Dataset

# %%
drive.mount('/content/gdrive', force_remount=True)
path = '/content/gdrive/MyDrive/Final Project/Dataset/Tomato/'
# Out:
# Mounted at /content/gdrive

# %%
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 64

# %%
train_datagen = ImageDataGenerator(rescale = 1/255, 
                                   validation_split = .2)

train_batches = train_datagen.flow_from_directory(
    path,
    target_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    class_mode = 'sparse',
    subset = 'training',
    shuffle = True, seed = 666
)

val_batches = train_datagen.flow_from_directory(
    path,
    target_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    class_mode = 'sparse',
    subset = 'validation',
    shuffle = True, seed = 666
)
# Out:
# Found 10389 images belonging to 6 classes.
# Found 2595 images belonging to 6 classes.

# %%
labels = train_batches.class_indices
classes_num = len(train_batches.class_indices)

# %%
labels
# Out:
# {'Tomato_BacterialSpot': 0,
#  'Tomato_EarlyBlight': 1,
#  'Tomato_Healthy': 2,
#  'Tomato_LateBlight': 3,
#  'Tomato_MosaicVirus': 4,
#  'Tomato_YellowLeafCurlVirus': 5}

# %%
import matplotlib.pyplot as plt

def plotimg(images):
  fig, axes = plt.subplots(1, 5, figsize=(40, 40))
  for img, ax in zip(images, axes):
    ax.imshow(img)
    ax.axis('off')
  plt.show()

# %%
imgs, labels = train_batches[0]
plotimg(imgs)
print(labels[:5])
# Out:
# [0. 5. 3. 2. 0.]

# %% [markdown]
# ## Model

# %%
model_tomato = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(16, (3,3), activation='relu',),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(8, (3,3), activation='relu',),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(classes_num, activation='softmax')
])    

model_tomato.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 16)        4624
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 8)         1160
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 8)        0
#  2D)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dropout (Dropout)           (None, 1568)              0
#
#  dense (Dense)               (None, 128)               200832
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 208,286
# Trainable params: 208,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
from tensorflow.keras.optimizers import Adam

model_tomato.compile(optimizer = Adam(learning_rate=0.0001), 
              loss = 'sparse_categorical_crossentropy', 
              metrics = ['accuracy'])

# %% [markdown]
# ## Train & Evaluate

# %%
# Train the model
history = model_tomato.fit(
            x = train_batches,
            validation_data = val_batches,
            epochs = 20,
            verbose = 1,
            #validation_steps = 5,
            #steps_per_epoch = 16,
            )
# Out:
# Epoch 1/20
# 163/163 [==============================] - 3979s 24s/step - loss: 1.3629 - accuracy: 0.4896 - val_loss: 1.0113 - val_accuracy: 0.6347
# Epoch 2/20
# 163/163 [==============================] - 33s 205ms/step - loss: 0.8781 - accuracy: 0.6879 - val_loss: 0.7027 - val_accuracy: 0.7823
# Epoch 3/20
# 163/163 [==============================] - 33s 205ms/step - loss: 0.6430 - accuracy: 0.7811 - val_loss: 0.5085 - val_accuracy: 0.8239
# Epoch 4/20
# 163/163 [==============================] - 33s 203ms/step - loss: 0.5204 - accuracy: 0.8215 - val_loss: 0.4547 - val_accuracy: 0.8432
# Epoch 5/20
# 163/163 [==============================] - 34s 207ms/step - loss: 0.4681 - accuracy: 0.8322 - val_loss: 0.4081 - val_accuracy: 0.8516
# Epoch 6/20
# 163/163 [==============================] - 33s 202ms/step - loss: 0.4293 - accuracy: 0.8479 - val_loss: 0.3926 - val_accuracy: 0.8582
# Epoch 7/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.4012 - accuracy: 0.8551 - val_loss: 0.3676 - val_accuracy: 0.8647
# Epoch 8/20
# 163/163 [==============================] - 33s 203ms/step - loss: 0.3678 - accuracy: 0.8634 - val_loss: 0.3467 - val_accuracy: 0.8713
# Epoch 9/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.3459 - accuracy: 0.8747 - val_loss: 0.3190 - val_accuracy: 0.8775
# Epoch 10/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.3264 - accuracy: 0.8809 - val_loss: 0.3049 - val_accuracy: 0.8871
# Epoch 11/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.3098 - accuracy: 0.8862 - val_loss: 0.2964 - val_accuracy: 0.8855
# Epoch 12/20
# 163/163 [==============================] - 33s 203ms/step - loss: 0.2931 - accuracy: 0.8947 - val_loss: 0.2813 - val_accuracy: 0.8906
# Epoch 13/20
# 163/163 [==============================] - 34s 206ms/step - loss: 0.2807 - accuracy: 0.8957 - val_loss: 0.2646 - val_accuracy: 0.8990
# Epoch 14/20
# 163/163 [==============================] - 33s 200ms/step - loss: 0.2685 - accuracy: 0.9028 - val_loss: 0.2557 - val_accuracy: 0.9052
# Epoch 15/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.2546 - accuracy: 0.9065 - val_loss: 0.2443 - val_accuracy: 0.9075
# Epoch 16/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.2415 - accuracy: 0.9118 - val_loss: 0.2464 - val_accuracy: 0.9106
# Epoch 17/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.2367 - accuracy: 0.9113 - val_loss: 0.2241 - val_accuracy: 0.9171
# Epoch 18/20
# 163/163 [==============================] - 33s 200ms/step - loss: 0.2258 - accuracy: 0.9165 - val_loss: 0.2111 - val_accuracy: 0.9206
# Epoch 19/20
# 163/163 [==============================] - 33s 200ms/step - loss: 0.2175 - accuracy: 0.9180 - val_loss: 0.2039 - val_accuracy: 0.9287
# Epoch 20/20
# 163/163 [==============================] - 33s 201ms/step - loss: 0.2070 - accuracy: 0.9245 - val_loss: 0.2034 - val_accuracy: 0.9225

# %%
import matplotlib.pyplot as plt
import numpy as np

# Retrieve history as lists
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(1, len(acc)+1)

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc, label='train acc')
plt.plot(epochs, val_acc, label='val acc')
plt.title('Training and validation accuracy')
plt.xticks(np.arange(0, len(acc)+1, 2))
plt.legend(['train acc', 'val acc'])
plt.show()
print("")

# Plot training and validation loss per epoch
plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.title('Training and validation loss')
plt.legend(['train loss', 'val loss'])
plt.xticks(np.arange(0, len(acc)+1, 2))
plt.show()

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(128, 128))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model_tomato.predict(images, batch_size=64)
  print(fn)
  print(list(labels)[np.argmax(classes[0])])
  # print(classes[0])
# Out:
#      <input type="file" id="files-b2abe690-cc88-413b-bac3-6b2bee6527a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2abe690-cc88-413b-bac3-6b2bee6527a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IU-TYLCV_img_1.jpg to IU-TYLCV_img_1.jpg
# Saving Tomato-Leaf-Curl-1600x800.jpg to Tomato-Leaf-Curl-1600x800.jpg
# Saving TYLCV leaflet cropped.png to TYLCV leaflet cropped.png
# IU-TYLCV_img_1.jpg
# Tomato_YellowLeafCurlVirus
# Tomato-Leaf-Curl-1600x800.jpg
# Tomato_YellowLeafCurlVirus
# TYLCV leaflet cropped.png
# Tomato_LateBlight

# %%
list(labels)[np.argmax(classes[0])]
# Out:
# 'Apple_cedar_rust'

# %% [markdown]
# ## Save & Convert Model

# %%
# save model
model_tomato.save('/content/model/planticure_model_tomato.h5')

# %%
tf.saved_model.save(model_tomato, '/content/model/')
# Out:
# INFO:tensorflow:Assets written to: /content/model/assets

# %%
# Convert model to tflite
tflite_model = tf.lite.TFLiteConverter.from_saved_model('/content/model/').convert()
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
# Save tflite model
import pathlib

pathlib.Path('/content/model/planticure_model_tomato.tflite').write_bytes(tflite_model)
# Out:
# 836748

# %%
# Save labels
with open('labels.txt', 'w') as f:
    f.write('\n'.join(labels))

# %% [markdown]
# #### Quantization

# %%
converter = tf.lite.TFLiteConverter.from_saved_model('/content/model')
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
import pathlib

pathlib.Path('/content/model/planticure_quantized_model.tflite').write_bytes(tflite_quantized_model)
# Out:
# 3416192

# %%
try:
    from google.colab import files
    files.download('/content/model/planticure_model_tomato.tflite')
    #files.download('/content/model/planticure_quantized_model.tflite')
    files.download('/content/model/planticure_model_tomato.h5')
    #files.download('/content/saved_model.pb')
    files.download('/content/labels.txt')
except:
    pass
